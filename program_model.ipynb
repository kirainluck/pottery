# %%
import pandas as pd
import numpy as np
import sklearn.metrics as sm
import joblib
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score

# %%
df = pd.read_csv('rc_contextCollection_completeSet.csv', delimiter=',')

# %%
df_ceramic = df[df['artifact']=='ceramic']

# %%
# %%capture
df_ceramic['pres_length'] = pd.to_numeric(df_ceramic['pres_length'], errors='coerce')
df_ceramic['pres_width'] = pd.to_numeric(df_ceramic['pres_width'], errors='coerce')
df_ceramic['pres_thick'] = pd.to_numeric(df_ceramic['pres_thick'], errors='coerce')
df_ceramic['pres_diam'] = pd.to_numeric(df_ceramic['pres_diam'], errors='coerce')

# %%
cols = ['classification', 'form', 'portion', 'fabric_color','pres_length','pres_width','pres_thick',
        'pres_diam','latitude', 'longitude']

categ_cols = ['classification', 'form', 'portion', 'fabric_color']

num_cols = ['pres_length', 'pres_width', 'pres_thick', 'pres_diam', 'latitude', 'longitude']

# %%
df2 = df_ceramic[cols]

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df3 = pd.DataFrame(imp.fit_transform(df2),
                   columns=df2.columns,
                   index=df2.index)

# %%
df4 = df3[categ_cols]
dt = LabelEncoder()
df5 = pd.DataFrame(columns=df4.columns, data=dt.fit_transform(df4.values.flatten()).reshape(df4.shape))
df6 = df3[num_cols]
df5.reset_index(drop=True, inplace=True)
df6.reset_index(drop=True, inplace=True)

# %%
bigdata = pd.concat([df5, df6], axis=1)
bigdata = bigdata.astype('float')

# %%
X = pd.DataFrame(bigdata[['classification', 'portion', 'fabric_color', 'pres_length', 'pres_width', 'pres_thick', 'pres_diam', 'latitude', 'longitude']])
y = pd.DataFrame(bigdata['form'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
params = {'n_estimators': 438, 'max_depth': 18, 'reg_alpha': 2, 'reg_lambda': 0, 'min_child_weight': 2, 'gamma': 0, 'learning_rate': 0.049135897324318896, 'colsample_bytree': 0.45999999999999996}

# %%
# %%capture
model = XGBClassifier(params)
r = model.fit(X_train, y_train)

# %%
# %%capture
y_pred = r.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7290322580645161

# %%
filename = 'pottery_classifier.joblib.pkl'

# %%
_ = joblib.dump(model, filename, compress=9)

# %%
classification_lst = list(df_ceramic.classification.unique())
classification_lst
# Out:
# ['coarseware',
#  'cookware',
#  'fineware',
#  'commonware',
#  'pithos',
#  'amphora',
#  'roof tile',
#  'loomweight',
#  'game marker',
#  'lamp',
#  'statuette',
#  'water pipe',
#  'unguentarium',
#  'lantern',
#  'beehive',
#  'bone',
#  'kiln lining',
#  'tile',
#  'kiln debris',
#  'lithic',
#  'glass',
#  'hypocaust tile',
#  'plaster']

# %%
p_lst = list(df_ceramic.portion.unique())
p_lst
# Out:
# ['handle',
#  'bodysherd',
#  'rim',
#  'base',
#  'profile',
#  'shoulder',
#  'ringfoot',
#  'toe',
#  'handle attachment',
#  nan,
#  'tile',
#  'rim and handle',
#  'rim fragment',
#  'stamped fragment',
#  'vertical neck',
#  'neck',
#  'square cube',
#  'trefoil rim',
#  'flaring rim',
#  'strap handle',
#  'partial',
#  'hooked rim',
#  'foot',
#  'rim with profile',
#  'incurved rim',
#  'ring base',
#  'nozzle',
#  'false ring foot',
#  'rim and handle attachment',
#  'beehive',
#  'neck with handle',
#  'flat base',
#  'bodysherd with bowing profile',
#  'pitcher fragments',
#  'base fragment',
#  'rim and profile',
#  'bodysherd with profile',
#  'toe fragment',
#  'handle frag',
#  'rim and neck',
#  'neck with handle attachment',
#  'shoulder bodysherd',
#  'horizontal handle',
#  'toe and rim',
#  'nozzle fragment',
#  'rim with handle attach',
#  'stamped',
#  'several bases',
#  'complete',
#  'corner',
#  'unknown',
#  'multiple portions',
#  'lug handle',
#  'offset shoulder',
#  'almond shaped rim',
#  'handle with profile',
#  'lip',
#  'bodysherd handle / rim',
#  'rim, base, bodysherd',
#  'rim and shoulder',
#  'handle and profile',
#  'bases',
#  'toe and profile',
#  'profile handle',
#  'rim with neck',
#  'base ringfoot',
#  'double rolled handle',
#  'collar',
#  'handle and body',
#  'neck and handle',
#  'bowing horizontal handle',
#  'molded rim',
#  'vertical rim',
#  'twisted rope handle',
#  'round handle',
#  'base and bodysherd',
#  'folded rim',
#  'lid',
#  'vertical rolled rim',
#  'base with thick squat ring foot',
#  'bodysherd with rouletting',
#  'bodysherd with handle attachment',
#  'thickened interior rim',
#  'spout',
#  'bowl with high foot',
#  'disk',
#  'interior fragment',
#  'stamped plaque',
#  'stem',
#  'lid handle',
#  '2 join bodysherds',
#  'shoulder fragment',
#  'amphora head',
#  'intact amphora',
#  'guttus lug handle',
#  'handle fragment',
#  '10 bodysherds',
#  'fragment of base',
#  'thickened rim',
#  '15 bodysherds',
#  'pinched handle',
#  '6 bodysherds',
#  'buttontoe fragment',
#  '18 bodysherds',
#  'mushroom toe with kiln tab',
#  'stump toe',
#  'ridged handle',
#  'flat toe',
#  '3 bodysherds',
#  'bodysherd, rim, with profile',
#  'rolled rim',
#  'vertical handle',
#  'vertical rim and handle',
#  'mushroom toe',
#  'offset wall',
#  'large stump toe',
#  'grooved rim',
#  'upright handle',
#  'horned handle',
#  'triangular handle',
#  'angular form',
#  'bodysherd at shoulder',
#  'possible toe',
#  'thicknd knob rim',
#  'ringfoot, flat base',
#  'bodysherd and handle fragment',
#  'strap handle, grooved',
#  'intact',
#  'base and profile',
#  'body',
#  'horizontal flat rim',
#  'small toe',
#  'tall neck of jug or amphora',
#  'handles and rims',
#  'bodysherd at base',
#  'shoulder with handle attachment',
#  'body, neck and handle attachment',
#  'shoulder and profile',
#  'join bodysherd',
#  'small ring handle',
#  'handle and rim profile',
#  'bodysherd with horizontal handle',
#  'stamped handle',
#  'base with profile',
#  'knuckle bone foot',
#  'flaring rim with ledge',
#  'ledge rim',
#  'possible lid',
#  'flattened angular rim',
#  'handles and bodysherd',
#  'joining bodysherd',
#  'thickened in turned rim',
#  'broken rim',
#  'neck fragment',
#  'sherd',
#  'shoulder or spout',
#  'loomweight',
#  'thickened rolled rim',
#  'shoulder and neck',
#  'base and wall fragment, ring foot',
#  'ringfoot fragment',
#  'top of handle fragment.',
#  'strap handle fragment',
#  'circular fragment',
#  '25 bodysherds',
#  'rim with lug handle',
#  '12 bodysherds',
#  '13 bodysherds',
#  '7 bodysherds',
#  'large handle',
#  'spout fragment',
#  'slag fragment',
#  'shoulder west handle',
#  'fragment. of foot',
#  'thumbrest',
#  'tripod foot',
#  'base of bowl',
#  'neck of bottle',
#  'rim of bowl',
#  'rim and body fragment',
#  'rolled rim, tall neck',
#  'wall west rim fragment',
#  'sliced handle',
#  'pantile?',
#  'base with wall fragment.',
#  'bodysherd (2 pieces now)',
#  'profile, neck or shoulder',
#  'lower handle',
#  'bodysherd with handle fragment',
#  'rim and neck fragment',
#  'knob toe',
#  'everted rim',
#  'shoulder join',
#  'wheelridged bodysherd',
#  'banded bodysherd',
#  'foot and profile',
#  'rolled handle',
#  'nozzle to strainer jug',
#  'han',
#  'molded horizontal rim',
#  'bowed handle',
#  'flanged rim',
#  'lid, jug stopper',
#  'possible rim',
#  'thunb tab to a locally produced kanthoros',
#  'lower body bodysherd',
#  'foot and bodysherd',
#  'rim neck and handle',
#  'upright rim',
#  'flat rim',
#  'raised edge',
#  'square fragment',
#  'triangular rim',
#  'orange',
#  'offset rim',
#  'beveled foot',
#  'square rim',
#  'ledge handle',
#  'base and nozzle',
#  'shoulder and handle',
#  '2 handle attachments',
#  '2 necks',
#  'floor',
#  'offset foot',
#  'wavy line motif',
#  'intact loomweight',
#  'pedestal foot',
#  'kiln lining',
#  'shoulder with neck',
#  'button toe',
#  'small handle',
#  'large toe',
#  'medium toe',
#  'long narrow toe',
#  'small button toe',
#  'rim form 4',
#  'pan tile frag',
#  'pithos lid',
#  'unfinished toe',
#  'l.west',
#  'lug handle (large)',
#  'molded shoulder fragment.',
#  'fragment',
#  '3 joined fragments of plate',
#  'base of plate',
#  'base with profile fragment?',
#  'horizontal rim fragment',
#  'joining rim',
#  'strap handle attachment',
#  'knob rim',
#  'folded rim fragment',
#  'bowl',
#  'wall',
#  'pofile',
#  '11 bodysherds',
#  'no slip',
#  'rooftile',
#  'rim and bodysherd',
#  'nearly intact form; missing rim',
#  'rim and wall fragment',
#  'combed bodysherd',
#  'broken toe',
#  'profile fragment',
#  'grooved strap handle',
#  '3 wheelridged bodysherds',
#  '6 out of 9 undiagnosed bodysherds',
#  'small handle fragment',
#  'half handle',
#  'vertical flaring rim',
#  'small rim fragment']

# %%
f_color_lst = list(df_ceramic.fabric_color.unique())
f_color_lst
# Out:
# [nan,
#  'looks CS',
#  'local orange',
#  'CS fabric',
#  'no slip',
#  'very fine',
#  'ringfoot',
#  'local fabric',
#  'whiteware',
#  'orange',
#  'hard gritty local',
#  'small',
#  'fabric looks CS',
#  'dark red fabric',
#  'red',
#  'darb red',
#  'tan',
#  'brown',
#  'pink',
#  'dark brown',
#  'pink orange',
#  'orange/red',
#  'orange brown',
#  'red brown',
#  'black',
#  'light brown',
#  'tan blslip',
#  'white',
#  'pink/blslip',
#  'brown/grey',
#  'grey',
#  'orange/grey',
#  'pinkish tan',
#  'pink tan',
#  'pink grey',
#  'yellow white',
#  'grey/pink',
#  'orange/tan',
#  'tan orange',
#  'local tan',
#  'local pink',
#  'local brown',
#  'exotic',
#  'local yellow/white',
#  'cream',
#  'clear',
#  'light orange',
#  'flattop',
#  'dark',
#  'orange CS fabric',
#  'gray gritty fabric',
#  'pitched local fab',
#  'unknown fab',
#  'local orange fabric',
#  'imported fabric',
#  'rectangular',
#  'flat everted rim',
#  'flatrim',
#  'horizontal everted rim',
#  'grooved rim',
#  'hellenistic black slip?',
#  'imitation pergamene form?',
#  'folded groove rim',
#  'imported',
#  'West Cilicia external flanged rim',
#  'fabric interior',
#  'imitation',
#  'black slip',
#  'ridge',
#  '104',
#  '105',
#  'wheel ridged',
#  'curving walls',
#  'incurved 414',
#  'black slip visible',
#  'curves',
#  '406',
#  'small form',
#  'thin cream fab',
#  'small straight round',
#  'square rolled rim',
#  '408',
#  'small handle',
#  'near toe',
#  'var fabric and hardness',
#  'orange flatbase found win 30m',
#  'found w_in 30m',
#  'grooved flange at rim 500',
#  'various 30m',
#  'one red stewpot',
#  'white red inclusions',
#  'black hard',
#  'hard cream_gray fabric',
#  'thick hard fabric',
#  'very hard',
#  'hard black 5',
#  'thick fabric',
#  'high foot black slip',
#  'light cream',
#  'CS like fabric',
#  'hard local orange',
#  'light pink',
#  'coarse light orange fabric',
#  'slightly grainy bright orange fabric',
#  'possibly fire damaged',
#  'dirty',
#  'overfired',
#  'nonoxydized gray,',
#  'gritty texture',
#  'gritty grainy fabric',
#  'yellow CS fabric',
#  'small white inclusions',
#  'mica visible',
#  'shiny thick white glazed interior, dull white exterior like 603, possibly same form',
#  'local ware',
#  'fine white fabric',
#  'small red inclusions',
#  'coarse local fabric',
#  'vertical rim with offset base',
#  'chalky cream',
#  'red slip with black paint',
#  'small, traces of black slip visible',
#  'small, traces of red slip visible',
#  'black slip interior, dribble ext',
#  'gritty red fabric/not native',
#  'oval straight vertical',
#  'smooth wall',
#  'Samaria 37 profile',
#  'double roll',
#  'red slip orange fabric',
#  'westtYR 7/6',
#  'West Cilicia fabric',
#  'worn gray fabric.',
#  'cypriot pink?',
#  'light gray, not native',
#  'fabric looks imported',
#  'maybe Antioch fabric',
#  'has fabric like CS or CRS',
#  'cream/tan',
#  'light tan fabric',
#  'looks like Antioch fabric',
#  'gritty with inclusions',
#  'soft red clay',
#  'rough hewn ext',
#  'very red fabric',
#  'red slip visible',
#  'dark cream',
#  'cream fabric and slip',
#  'slip visible',
#  'shiny orange fabric',
#  'very worn',
#  'slip gone',
#  'red slip',
#  'trace of slip',
#  'combed',
#  'slightly reddish',
#  'small ring',
#  'upturned, handle attachment',
#  'grooved',
#  'upturned everted, local',
#  'pink fine fabric',
#  'on road',
#  'Bickici fabric',
#  'decorated',
#  'rouletting',
#  'Sagallassos ware',
#  'mushroom',
#  'burnished?',
#  'broken double roll',
#  'possible black slip',
#  'seawater slip',
#  'half',
#  'with molding',
#  'gray',
#  'worn',
#  'blackened',
#  'hard red',
#  'possible Syedra fabric',
#  'rim',
#  'black slip exterior',
#  'rouletting on wall',
#  'gritty orange',
#  'horizontal upturned rim',
#  'worn local fabric',
#  'no slip visible',
#  'Syedra fabric?',
#  'white fabric but small',
#  'from looted tomb',
#  'upright rim',
#  'exterior looks slipped',
#  'observed',
#  'pink CS fabric, no slip',
#  'yellow surface',
#  'hard gritty fabric',
#  'thickened interior rim',
#  'possible neck',
#  'mostly same fabric as cypriot fineware',
#  'West Cilicia whiteware',
#  'reddish yellow',
#  'soft local orange fabric',
#  'white and orange local fab',
#  'local tan and orange',
#  'coarse fabric',
#  'soft cream',
#  'pale yellow',
#  'brown gritty',
#  'soft cream fabric,  very pale brown',
#  'soft cream, pink',
#  'joining piece missing',
#  'pink solft',
#  'soft orange fabric',
#  'yellow fabric',
#  'black slip below rim',
#  'carinated profile',
#  'possible SKS fabric',
#  'orange pink',
#  'soft pink',
#  'fabric looks too light',
#  'yellowish red slip',
#  'slightly pinkish fabric',
#  'light brown with many small dark inclusions',
#  'light tan clay',
#  'soft red orange',
#  'gritty cream',
#  'extremely coarse with unclusions like antioch fabric but orange',
#  'coarse gritty local orange fabric',
#  'gritty',
#  'light red',
#  'solf local orange',
#  'blue',
#  'gritty local orange fabric',
#  'gritty red fabric',
#  'hard fabric,  light brown',
#  'gritty light brown fabric',
#  'yellow brown fabric',
#  'very pale brown',
#  'soft pink clay',
#  'soft light brown fabric',
#  'soft red',
#  'green glaze visible interior',
#  'possibly palestinian?',
#  'fine grainy light brown/whiteware',
#  'mottled brown and black spots against brown surface fabric. hard but coarse, mica present',
#  'dark orange local fabric',
#  'orange local fabric, very worn',
#  'yellowish red',
#  'reddish fabric, black and white spec inclusions',
#  'dark orange fabric',
#  'high in mica, blackened interior',
#  'mica present',
#  'light tan fabric, very high in mica',
#  'fractional version',
#  'hard brownish, red fabric. lots of mica, small white inclusions.',
#  'slip visible on both',
#  'coarse orange fabric',
#  'local orange/red',
#  'local red',
#  'local grey',
#  'round bosses',
#  'whitish',
#  'fabric core',
#  'ridging',
#  'possible stamp',
#  'raised ridge',
#  'incurved rim',
#  'coarse blackish fabric at core, muddy orange on surface;',
#  'soft clay',
#  'fabric looks local orange',
#  'chalky red',
#  'fabric looks right but worn,',
#  'slipped black and red',
#  'reddish brown',
#  'fabric similar to one in Study Collection',
#  'blackened exterior',
#  'hard, gritty red',
#  'new, dull orange fabric',
#  'foreign red fab',
#  'double rolled handle',
#  'too dark for cs',
#  'thickened with grooves directly below',
#  '45',
#  'dark pink',
#  'light brown, gritty',
#  'red exterior',
#  'light brown, soft',
#  'very dark greyish brown',
#  'dark grey',
#  'very gritty with tons of inclusions',
#  'coarse orange; numerous inclusions; does not look local',
#  'fine imitation ware',
#  'pink CS fabric',
#  'gray CS fabric',
#  'yellow and red parts',
#  'pink red',
#  'yellow orange',
#  'deep red and yellow',
#  'orange pink exterior, gray interior',
#  'fineware',
#  'grooved lines',
#  'red&black slip vis',
#  'crosshatches',
#  'dark gray',
#  'black slip interior',
#  'thickened',
#  'orange and gray',
#  'local pink, inclusions',
#  'piink/orange, very hard fabric with air holes',
#  'dark orange',
#  'gritty local',
#  'local gritty orange',
#  'base and wall',
#  'gray with black inclusions',
#  'fine fabric',
#  'Gley 2 2.5/1',
#  'red orange',
#  'sloping wall',
#  'hard white',
#  'light hard',
#  'blackend interior',
#  'Antioch fab?',
#  'slipped?',
#  'thick coarse local orange',
#  'rouletting on rim',
#  'grooves beneath',
#  'with hatchmarks',
#  'handle',
#  'micaceous',
#  'rim grooved 3cm below rim',
#  "fabric doesn't look right for rhodian",
#  'fabric is wrong for crs. brown fab.',
#  'very large, local fabric?',
#  'fabric resembles Cypriot fineware',
#  'fabric feels coarse',
#  'large white inclusions',
#  'dark, not regional',
#  'fabric whitish but not coarse like local whiteware',
#  'soft orange SKS fabric?',
#  'banded',
#  'double fold',
#  'not reddish, but many inclusions',
#  'horizontal handle',
#  'orange gritty fabric with large white inclusions',
#  'orange with large stone inclusions',
#  'fabric looks imported, tan green fabric',
#  'fairly fine dark red fabric, dark interior',
#  'gritty red, mica',
#  'light red brown',
#  'very coarse, gritty',
#  'soft light brown Bickici fabric',
#  'small coarse grains',
#  'fabric looks Cypriot',
#  'pink interior',
#  '2-toned clay, orange exterior, gray interior',
#  'red with large white inclusions']

# %% [markdown]
# Пишем маппинги в файл для программы

# %%
clf_lst = [x for x in classification_lst if str(x) != 'nan']
portion_lst = [x for x in p_lst if str(x) != 'nan']
fabric_color_lst = [x for x in f_color_lst if str(x) != 'nan']
names_all = [x for x in dt.classes_ if str(x) != 'nan']

# %%
name_mapping = dict(zip(dt.classes_, dt.transform(dt.classes_)))
with open("C:\Projects\pottery\ctglists.py", "w") as dict_file:
    dict_file.write('name_mapping = ')
    dict_file.write(repr(name_mapping))
    dict_file.write('\n')
    dict_file.write('names_all = ')
    dict_file.write(repr(names_all))
    dict_file.write('\n')
    dict_file.write('clf_lst = ')
    dict_file.write(repr(clf_lst))
    dict_file.write('\n')
    dict_file.write('portion_lst = ')
    dict_file.write(repr(portion_lst))
    dict_file.write('\n')
    dict_file.write('fabric_color_lst = ')
    dict_file.write(repr(fabric_color_lst))

# %%
# %%capture
#y_pred = r.predict(X_test)

# %%
X_test
# Out:
#       classification  portion  fabric_color  pres_length  pres_width  \
# 8095            35.0     84.0         365.0          8.0         2.0
# 31             134.0     84.0         426.0          8.0         2.0
# 1509            35.0    261.0         697.0          8.0         2.0
# 2980            35.0     84.0         426.0          8.0         2.0
# 5926           141.0     84.0         426.0          8.0         2.0
# ...              ...      ...           ...          ...         ...
# 5685           141.0    551.0         426.0         12.0         2.0
# 1515           197.0     84.0         349.0          8.0         2.0
# 7477           197.0    508.0         426.0          8.0         2.0
# 1070           197.0     84.0         426.0          8.0         2.0
# 794            197.0    508.0         426.0          8.0         2.0
#
#       pres_thick  pres_diam   latitude  longitude
# 8095         1.0       10.0  36.177385  32.394768
# 31           1.0       10.0  36.221134  32.436667
# 1509         1.0       10.0  36.223264  32.456546
# 2980         1.0       10.0  36.168415  32.403799
# 5926         1.0       10.0  36.455807  32.447161
# ...          ...        ...        ...        ...
# 5685         2.0       10.0  36.427175  32.410385
# 1515         1.0       10.0  36.221221  32.465339
# 7477         1.0       10.0  36.175328  32.382141
# 1070         1.0       10.0  36.190525  32.461607
# 794          1.0       10.0  36.189925  32.460580
#
# [1860 rows x 9 columns]

# %%
df = pd.DataFrame([[35.0, 84.0, 365.0, 8.0, 2.0, 1.0, 10.0, 36.177385, 32.394768]], 
                  columns=['classification','portion','fabric_color','pres_length','pres_width','pres_thick','pres_diam','latitude','longitude'])

# %%
df
# Out:
#    classification  portion  fabric_color  pres_length  pres_width  pres_thick  \
# 0            35.0     84.0         365.0          8.0         2.0         1.0
#
#    pres_diam   latitude  longitude
# 0       10.0  36.177385  32.394768

# %%
y_pred = r.predict(df)

# %%
y_pred
# Out:
# array([35.])
